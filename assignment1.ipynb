# %% [markdown]
# # Assignment 1 — QANet
#
# **COMP5329 / Deep Learning — University of Sydney, Semester 1 2026**
#
# Run each section in order. Sections 0–1 are one-time setup steps; Sections 2–4 are the main training and evaluation pipeline.

# %%
from google.colab import drive
drive.mount('/content/drive')

# Adjust this path if your repo is stored elsewhere in Drive.
PROJECT_ROOT = "/content/drive/MyDrive/Assignment1--2026"
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Install Python dependencies (run once per session)
# !pip install -r {PROJECT_ROOT}/requirements.txt -q
# !python -m spacy download en
# Out:
# ⚠ As of spaCy v3.0, shortcuts like 'en' are deprecated. Please use the
# full pipeline package name 'en_core_web_sm' instead.
# Collecting en-core-web-sm==3.8.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.8.0/en_core_web_sm-3.8.0-py3-none-any.whl (12.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 53.7 MB/s eta 0:00:0000:0100:01
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')
# ⚠ Restart to reload dependencies
# If you are in a Jupyter or Colab notebook, you may need to restart Python in
# order to load all the package's dependencies. You can do this by selecting the
# 'Restart kernel' or 'Restart runtime' option.

# %% [markdown]
# ---
# ## Section 0 — Environment Setup
#
# Mount Google Drive and install dependencies.

# %%
import sys, os

if PROJECT_ROOT not in sys.path:
    sys.path.insert(0, PROJECT_ROOT)

os.chdir(PROJECT_ROOT)
print("Working directory:", os.getcwd())
# Out:
# Working directory: /content/drive/MyDrive/Assignment1--2026

# %% [markdown]
# ---
# ## Section 1 — Download Data *(delete before submitting)*
#
# Downloads the pre-built mini dataset (sampled SQuAD v1.1 train + full dev set,
# with GloVe vectors filtered to the mini vocabulary) from GitHub Releases into `_data/`.
#
# > **One-time step.** Once `_data/` exists on your Drive, delete this section before submission.

# %%
from Tools.download import download_mini

download_mini(data_dir="_data")
# Out:
# ============================================================
# Step 1 / 2  —  Mini dataset (SQuAD + GloVe)
# ============================================================
#   [skip] Mini dataset already present in _data/.
#
# ============================================================
# Step 2 / 2  —  spaCy language model
# ============================================================
# Downloading spaCy model 'en' …
# Collecting en-core-web-sm==3.8.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.8.0/en_core_web_sm-3.8.0-py3-none-any.whl (12.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 98.9 MB/s eta 0:00:00
# ⚠ As of spaCy v3.0, shortcuts like 'en' are deprecated. Please use the
# full pipeline package name 'en_core_web_sm' instead.
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')
# ⚠ Restart to reload dependencies
# If you are in a Jupyter or Colab notebook, you may need to restart Python in
# order to load all the package's dependencies. You can do this by selecting the
# 'Restart kernel' or 'Restart runtime' option.
#
# Mini dataset download complete.

# %% [markdown]
# ---
# ## Section 2 — Preprocess Data *(delete before submitting)*
#
# Tokenises the SQuAD JSON files, builds word/char vocabularies from GloVe, and writes padded index tensors to `_data/`.
#
# > **One-time step.** Once `_data/*.npz` exists on your Drive, delete this section before submission. Re-run only if you change `para_limit`, `ques_limit`, or other shape parameters.

# %%
from Tools.preproc import preprocess

preprocess(
    train_file="_data/squad/train-mini.json",
    dev_file="_data/squad/dev-v1.1.json",
    glove_word_file="_data/glove/glove.mini.txt",
    target_dir="_data",
    para_limit=400,
    ques_limit=50,
)
# Out:
# Generating train examples…
# 100%|██████████| 150/150 [00:06<00:00, 23.50it/s]
#   30293 questions in total
# Generating dev examples…
# 100%|██████████| 48/48 [00:02<00:00, 17.23it/s]
#   10570 questions in total
# Generating word embedding…
# 114806it [00:12, 9294.39it/s]
#   53038 / 57695 tokens have a corresponding word embedding vector
# Generating char embedding…
#   748 tokens have a corresponding embedding vector
# Processing train examples…
# 100%|██████████| 30293/30293 [00:12<00:00, 2428.67it/s]
#   Built 30169 / 30293 instances
# Processing dev examples…
# 100%|██████████| 10570/10570 [00:05<00:00, 1853.05it/s]
#   Built 10465 / 10570 instances
# Saving word embedding…
# Saving char embedding…
# Saving train eval…
# Saving dev eval…
# Saving word dictionary…
# Saving char dictionary…
# Saving dev meta…
#
# Preprocessing complete.
#   Outputs → _data/
# {'train_record_file': '_data/train.npz',
#  'dev_record_file': '_data/dev.npz',
#  'word_emb_file': '_data/word_emb.json',
#  'char_emb_file': '_data/char_emb.json',
#  'train_eval_file': '_data/train_eval.json',
#  'dev_eval_file': '_data/dev_eval.json',
#  'word2idx_file': '_data/word2idx.json',
#  'char2idx_file': '_data/char2idx.json',
#  'dev_meta_file': '_data/dev_meta.json'}

# %% [markdown]
# ---
# ## Section 3 — Train
#
# Trains QANet on SQuAD v1.1 and saves the best checkpoint to `_model/model.pt`.

# %%
from TrainTools.train import train

results = train(
    # ── data paths (must match preprocess outputs) ──────────────────────
    train_npz       = "_data/train.npz",
    dev_npz         = "_data/dev.npz",
    word_emb_json   = "_data/word_emb.json",
    char_emb_json   = "_data/char_emb.json",
    train_eval_json = "_data/train_eval.json",
    dev_eval_json   = "_data/dev_eval.json",
    save_dir        = "_model",
    log_dir         = "_log",

    # ── training loop ────────────────────────────────────────────────────
    num_steps  = 600,#初始是60000
    batch_size = 8,
    seed       = 42,

    # ── vanilla recipe: SGD, no scheduler, NLL loss ───────────────────────
    optimizer_name = "sgd",
    scheduler_name = "lambda",
    loss_name      = "qa_nll",
)

print(f"Best F1: {results['best_f1']:.4f}  |  Best EM: {results['best_em']:.4f}")
# Out:
#   0%|          | 0/200 [00:01<?, ?it/s]
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /tmp/ipykernel_23891/1932420728.py in <cell line: 0>()
#       1 from TrainTools.train import train
#       2
# ----> 3 results = train(
#       4     # ── data paths (must match preprocess outputs) ──────────────────────
#       5     train_npz       = "_data/train.npz",
#
# /content/drive/MyDrive/Assignment1--2026/TrainTools/train.py in train(train_npz, dev_npz, word_emb_json, char_emb_json, train_eval_json, dev_eval_json, save_dir, log_dir, ckpt_name, batch_size, num_steps, checkpoint, val_num_batches, test_num_batches, seed, grad_clip, early_stop, optimizer_name, scheduler_name, loss_name, norm_name, norm_groups, learning_rate, beta1, beta2, eps, weight_decay, momentum, lr_step_size, lr_gamma, para_limit, ques_limit, char_limit, d_model, num_heads, glove_dim, char_dim, dropout, dropout_char, pretrained_char, use_batch_norm, activation, init_name)
#     152         steps_this_block = min(checkpoint, num_steps - step0)
#     153
# --> 154         train_loss = train_single_epoch(
#     155             model, optimizer, scheduler, _train_iter,
#     156             steps_this_block, grad_clip, loss_fn, DEVICE,
#
# /content/drive/MyDrive/Assignment1--2026/TrainTools/train_utils.py in train_single_epoch(model, optimizer, scheduler, data_iter, steps, grad_clip, loss_fn, device, global_step)
#      28         y1, y2     = y1.to(device),   y2.to(device)
#      29
# ---> 30         p1, p2 = model(Cwid, Ccid, Qwid, Qcid)
#      31         loss   = loss_fn(p1, p2, y1, y2)
#      32         loss_list.append(float(loss.item()))
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1774             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1775         else:
# -> 1776             return self._call_impl(*args, **kwargs)
#    1777
#    1778     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1785                 or _global_backward_pre_hooks or _global_backward_hooks
#    1786                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1787             return forward_call(*args, **kwargs)
#    1788
#    1789         result = None
#
# /content/drive/MyDrive/Assignment1--2026/Models/qanet.py in forward(self, Cwid, Ccid, Qwid, Qcid)
#      66         Qw, Qc = self.word_emb(Qwid), self.char_emb(Qcid)
#      67
# ---> 68         C, Q = self.emb(Cc, Cw), self.emb(Qc, Qw)
#      69         C = self.context_conv(C)
#      70         Q = self.question_conv(Q)
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1774             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1775         else:
# -> 1776             return self._call_impl(*args, **kwargs)
#    1777
#    1778     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1785                 or _global_backward_pre_hooks or _global_backward_hooks
#    1786                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1787             return forward_call(*args, **kwargs)
#    1788
#    1789         result = None
#
# /content/drive/MyDrive/Assignment1--2026/Models/embedding.py in forward(self, ch_emb, wd_emb)
#      39         ch_emb = ch_emb.permute(0, 2, 1, 3)  # [B, d_char, L, char_len]
#      40         ch_emb = self.drop_char(ch_emb)
# ---> 41         ch_emb = self.conv2d(ch_emb)
#      42         ch_emb = self.act(ch_emb)
#      43         ch_emb, _ = torch.max(ch_emb, dim=3)  # [B, d_char, L]
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1774             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1775         else:
# -> 1776             return self._call_impl(*args, **kwargs)
#    1777
#    1778     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1785                 or _global_backward_pre_hooks or _global_backward_hooks
#    1786                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1787             return forward_call(*args, **kwargs)
#    1788
#    1789         result = None
#
# /content/drive/MyDrive/Assignment1--2026/Models/conv.py in forward(self, x)
#     173
#     174     def forward(self, x):
# --> 175         return self.pointwise_conv(self.depthwise_conv(x))
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1774             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1775         else:
# -> 1776             return self._call_impl(*args, **kwargs)
#    1777
#    1778     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1785                 or _global_backward_pre_hooks or _global_backward_hooks
#    1786                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1787             return forward_call(*args, **kwargs)
#    1788
#    1789         result = None
#
# /content/drive/MyDrive/Assignment1--2026/Models/conv.py in forward(self, x)
#     137
#     138         # Reshape into groups: [B, G, C_in_g, H_out, W_out, k, k]
# --> 139         x_unf = x_unf.contiguous().view(B, G, C_in_g, H_out, W_out, k, k)
#     140         # Weight by group: [G, C_out_g, C_in_g, k, k]
#     141         w = self.weight.view(G, C_out_g, C_in_g, k, k)
#
# RuntimeError: shape '[8, 64, 0, 400, 64, 5, 5]' is invalid for input of size 81920000

# %%
import os
print(os.getcwd())
print(PROJECT_ROOT)
# Out:
# /content/drive/MyDrive/Assignment1--2026
# /content/drive/MyDrive/Assignment1--2026

# %% [markdown]
# ---
# ## Section 4 — Evaluate
#
# Loads the saved checkpoint and runs inference on the full dev set.

# %%
from EvaluateTools.evaluate import evaluate

metrics = evaluate(
    dev_npz       = "_data/dev.npz",
    word_emb_json = "_data/word_emb.json",
    char_emb_json = "_data/char_emb.json",
    dev_eval_json = "_data/dev_eval.json",
    save_dir      = "_model",
    log_dir       = "_log",
    ckpt_name     = "model.pt",
)

print(f"F1: {metrics['f1']:.4f}  |  EM: {metrics['exact_match']:.4f}  |  Loss: {metrics['loss']:.6f}")
